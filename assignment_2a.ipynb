# %% [markdown]
# <a href="https://colab.research.google.com/github/tanushkapatil/DEVL/blob/main/assignment_2a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = {
    "calories" : [1, 2, 3, 4],
    "duration" : [60, 70, 80, 90]
}
df = pd.DataFrame(data)
print(df)
print(df.loc[0])
print(df.loc[1, "duration" ])  #column label
print(df.loc[[0,1]])

df = pd.DataFrame(data, index =  ["day1", "day2", "day3", "day4"])
print(df)

df = pd.read_csv('data.csv')
print(df)

df.head()

df.tail()

df.describe() #describe the overall dataset
print(df.to_string)
df.info()

df.dtypes

header = ["a" , "b"]
df.columns =header
print(df)

print(df.to_string()) #print out the entire df in a way that is easy to read
new_df = df.dropna #deletes the row having a null value
# Out:
#    calories  duration
# 0         1        60
# 1         2        70
# 2         3        80
# 3         4        90
# calories     1
# duration    60
# Name: 0, dtype: int64
# 70
#    calories  duration
# 0         1        60
# 1         2        70
#       calories  duration
# day1         1        60
# day2         2        70
# day3         3        80
# day4         4        90
#    age   height(in cm)
# 0   12             140
# 1   24             159
# 2   37             172
# 3   40             164
# 4   54             167
# 5   33             162
# 6   41             170
# 7   56             166
# 8   47             164
# 9   48             171
# <bound method DataFrame.to_string of    age   height(in cm)
# 0   12             140
# 1   24             159
# 2   37             172
# 3   40             164
# 4   54             167
# 5   33             162
# 6   41             170
# 7   56             166
# 8   47             164
# 9   48             171>
# ...

# %%
df = pd.read_csv('iris.csv')
print(df)
df.describe()
print(df.loc[3])
df.head()
#df.tail()
df.info()
header = ["a","b","c","d","e"]
df.columns =header
print(df)
print(df.to_string())
new_df = df.dropna #deletes the row having a null value
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]
# sepal.length       4.6
# sepal.width        3.1
# petal.length       1.5
# petal.width        0.2
# ...

# %%
import pandas as pd
df = pd.read_json('data.json')

print(df.to_string())
df.info()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df.head()
#df.tail()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 6.6 KB

# %%
filter_df = df[df["Pulse"]>100]
print(filter_df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [110 rows x 4 columns]

# %%
print(df["Duration"])

print(df[["Duration" , "Calories"]])
# Out:
# 0      60
# 1      60
# 2      60
# 3      45
# 4      45
#        ..
# 164    60
# 165    60
# 166    60
# 167    75
# 168    75
# Name: Duration, Length: 169, dtype: int64
#      Duration  Calories
# 0          60     409.1
# 1          60     479.0
# 2          60     340.0
# 3          45     282.4
# 4          45     406.0
# ..        ...       ...
# 164        60     290.8
# 165        60     300.4
# 166        60     310.2
# 167        75     320.4
# 168        75     330.4
#
# [169 rows x 2 columns]
